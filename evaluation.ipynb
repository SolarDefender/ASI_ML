# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
# %run training.ipynb

# %%
results = {}
for name, model in models.items():
    predictions = model.predict(X_test)
    mae = mean_absolute_error(Y_test, predictions)
    mse = mean_squared_error(Y_test, predictions)
    r2 = r2_score(Y_test, predictions)
    results[name] = {'MAE': mae, 'MSE': mse, 'R2': r2}

results_df = pd.DataFrame(results).T
print(results_df)
# Out:
#                            MAE           MSE        R2
# Linear Regression  4478.295649  3.104126e+07  0.225241
# Random Forest      2670.142537  1.521745e+07  0.619018
# Decision Tree      3238.581902  3.002448e+07  0.247251

# %%
metrics = ['MAE', 'MSE', 'R2']
results_values = [results_df['MAE'], results_df['MSE'], results_df['R2']]

plt.figure(figsize=(15, 5))

for i, metric in enumerate(metrics):
    plt.subplot(1, 3, i + 1)
    results_df[metric].plot(kind='bar')
    plt.title(metric)
    plt.ylabel('Wartości')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
